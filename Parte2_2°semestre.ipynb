# %% [markdown]
# <a href="https://colab.research.google.com/github/jonataslima7991-commits/Localhost8501/blob/main/Parte2_2%C2%B0semestre.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
'''Classe para implementar funcionálidades básicas para manipular um objeto do tipo Pessoa
Author: jonatas
Date: 27/mai/2026
'''
class Pessoa:

  #Método para criar o objeto em memória
  def __init__(self, nome, idade, altura, peso):
    self.nome = nome
    self.idade = idade
    self.altura = altura
    self.peso = peso

  #Método para exibir dados de uma pessoa

  def exibirDadosPessoa(self):
    print(f'Nome: {self.nome} tem {self.idade} anos, {self.altura} de altura e {self.peso} kilos')
    print(f"Pela sua idade você é considerado {self.classificarIdade()}")
    print(f"Classificação do IMC: {self.classificarIMC()}")
    print(f"Sua altura é de {self.altura}")
    print(f"Você tem mais idade que {self.classificarAltura}")
#Método para classificar a idade de uma pessoa

  def classificarIdade(self):
    if self.idade < 2:
      return "Bebê"
    elif self.idade < 12:
      return "Criança"
    elif self.idade < 19:
      return "Adolescente"
    elif self.idade < 60:
      return "Adulto"
    else:
      return "Idoso"
  def calcularIMC(self):
      return self.peso/(self.altura * self.altura)

#Método para classificar a idade de uma pessoa

  def classificarIMC(self):
    imc = self.calcularIMC()
    if imc < 18:
      return "Abaixo do peso"
    elif imc < 25:
      return "Peso Ideal"
    elif imc < 30:
      return "Levemente acima do peso"
    elif imc < 35:
      return "Obesidade Grau 1"
    elif imc < 40:
      return "Obesidade Grau 2"
    else:
      return "Obesidade Grau 3"

  def classificarAltura(self):
    altura = self.altura()
    if altura < 1.60:
      return "Baixa"
    elif altura < 1.75:
      return "Mediana"
    elif altura < 1.90:
      return "Alto"
    else:
      return "Super Alto!!!"


  def compararIdade(self):
    altura = self.altura()
    if idade1 < idade22:
      print("{} é mais velho que {}".format(idade1, idade2))

# %%
'''
Descrição: Célula de código para instanciar
objetos da classe Pessoa
'''

#Instanciando
nome1 = input("Nome : ")
idade1 = int(input("Idade : "))
altura1 = float(input("Altura: "))
peso1 = float(input("peso: "))
p1 = Pessoa(nome1, idade1, altura1, peso1)

#Instanciando
nome2 = input("Nome : ")
idade2 = int(input("Idade : "))
altura2 = float(input("Altura: "))
peso2 = float(input("peso: "))
p2 = Pessoa(nome2, idade2, altura2, peso2)

#Exibindo os dados dos objetos gerados
p1.exibirDadosPessoa()
p2.exibirDadosPessoa()
# Out:
# Nome : jhw
# Idade : 45
# Altura: 1.5
# peso: 59
# Nome : klw
# Idade : 78
# Altura: 1.4
# peso: 52
# Nome: jhw tem 45 anos, 1.5 de altura e 59.0 kilos
# Pela sua idade você é considerado Adulto
# Classificação do IMC: Levemente acima do peso
# Sua altura é de 1.5
# Você tem mais idade que <bound method Pessoa.classificarAltura of <__main__.Pessoa object at 0x7a6b96a7ddc0>>
# Nome: klw tem 78 anos, 1.4 de altura e 52.0 kilos
# Pela sua idade você é considerado Idoso
# Classificação do IMC: Levemente acima do peso
# Sua altura é de 1.4
# Você tem mais idade que <bound method Pessoa.classificarAltura of <__main__.Pessoa object at 0x7a6b96494c20>>
